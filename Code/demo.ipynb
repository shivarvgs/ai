# %% [markdown]
# # 10 May 2026

# %% [markdown]
# ##### Deactivate --> deactivate existing python virtual environment
# ##### python -m venv EnvironmentName --> this will create a environment. It's a virtual environment. It's converting the code into machine undestandable language
# ##### Environment name\Scripts\activate --> activate the required python environment
# ## GIT CONFIGURATION:
# ##### open cmd, type git.
# ##### git config --global user.name "shivarvgs"
# ##### git config --global user.email "shivarvgs3637@gmail.com"
